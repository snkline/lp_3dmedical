# %% [markdown]
# <a href="https://colab.research.google.com/github/snkline/lp_3dmedical/blob/main/Part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %%
import nibabel as nib

t1_image = nib.load("/content/t1/IXI102-HH-1416-T1_fcm.nii.gz")
t1_image_data = t1_image.get_fdata()

t2_image = nib.load("/content/t2/IXI102-HH-1416-T2_reg_fcm.nii.gz")
t2_image_data = t2_image.get_fdata()

# %%
import matplotlib.pyplot as plt

t1_image_plt = plt.imshow(t1_image_data[:,60,:])

# %%
t2_image_plt = plt.imshow(t2_image_data[:,60,:])
